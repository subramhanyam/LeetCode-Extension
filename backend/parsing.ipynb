# %%
import requests
from bs4 import BeautifulSoup

# %%
url = "https://leetcode.com/problems/two-sum/description/"
response = requests.get(url)

# %%
soup = BeautifulSoup(response.text, "html.parser")

# %%
soup
# Out:
# <!DOCTYPE html>
# <html lang="en-US"><head><title>Just a moment...</title><meta content="text/html; charset=utf-8" http-equiv="Content-Type"/><meta content="IE=Edge" http-equiv="X-UA-Compatible"/><meta content="noindex,nofollow" name="robots"/><meta content="width=device-width,initial-scale=1" name="viewport"/><meta content="default-src 'none'; script-src 'nonce-HSD6shS7oblneHld5YH98h' 'unsafe-eval' https://challenges.cloudflare.com; script-src-attr 'none'; style-src 'unsafe-inline'; img-src 'self' https://challenges.cloudflare.com; connect-src 'self' https://challenges.cloudflare.com; frame-src 'self' https://challenges.cloudflare.com blob:; child-src 'self' https://challenges.cloudflare.com blob:; worker-src blob:; form-action http: https:; base-uri 'self'" http-equiv="content-security-policy"/><style>*{box-sizing:border-box;margin:0;padding:0}html{line-height:1.15;-webkit-text-size-adjust:100%;color:#313131;font-family:system-ui,-apple-system,BlinkMacSystemFont,"Segoe UI",Roboto,"Helvetica Neue",Arial,"Noto Sans",sans-serif,"Apple Color Emoji","Segoe UI Emoji","Segoe UI Symbol","Noto Color Emoji"}body{display:flex;flex-direction:column;height:100vh;min-height:100vh}.main-content{margin:8rem auto;padding-left:1.5rem;max-width:60rem}@media (width <= 720px){.main-content{margin-top:4rem}}#challenge-error-text{background-image:url("data:image/svg+xml;base64,...");background-repeat:no-repeat;background-size:contain;padding-left:34px}</style><meta content="360" http-equiv="refresh"/></head><body><div class="main-wrapper" role="main"><div class="main-content"><noscript><div class="h2"><span id="challenge-error-text">Enable JavaScript and cookies to continue</span></div></noscript></div></div><script nonce="HSD6shS7oblneHld5YH98h">(function(){window._cf_chl_opt = {cFPWv: 'g',cH: 'XQ2VEHpcCnSXHi.NMxP._n7v8fMQUtubu2rEYtUlhG0-1780829901-1.2.1.1-kBqqxXEbS9iwLfRQVuRIcPHgXg3uYMLRfU0PC1.wzPvgXAQzokyz_IIA65Ui_aZM',cITimeS: '1780829901',cN: 'HSD6shS7oblneHld5YH98h',cRay: 'a07f2425fc9326a7',cTplB: '0',cTplC:0,cTplO:0,cTplV:5,cType: 'managed',cUPMDTk:"/problems/two-sum/description/?__cf_chl_tk=CO6DuE_77rWwdO6aPCZCXKmSTJAyG3CWrzPeLNC7F74-1780829901-1.0.1.1-48G09Y4DyFyaD5ur0HPpASBfyjUwqb2n4iDJhPcldkI",cvId: '3',cZone: 'leetcode.com',fa:"/problems/two-sum/description/?__cf_chl_f_tk=CO6DuE_77rWwdO6aPCZCXKmSTJAyG3CWrzPeLNC7F74-1780829901-1.0.1.1-48G09Y4DyFyaD5ur0HPpASBfyjUwqb2n4iDJhPcldkI",md: '1wPVVysshdJR10j9Y77Kx02JMPbZhCmh7qw6bKN2kNo-1780829901-1.2.1.1-OmfVtUcVNW2lOhkQ_ZT6YACHiJA9OyqLw3TAKv7X1o5MKKqlJL3XxABN1C.CfDGJvvbI3qGk1gJ0a1.9boMLwGufk6IrRTU30jAXUt1eB_LZIIRmkSmESXx9ykiaLklPNBD1krHXAPMlUYzKk1FB3zV7F3PGVzG1PoMRZISmLIQHa7pG6CH11OwRNHMu85HtjzhQqSavXaGsWVeMfrMZdrykUtRea3IfscmaV7mSkWw2HPrNIvNAouxpt7CRni9ekd4m.jwtosvwiaehes6y.3OXSZTjm4YLY_aFnBlqcBo.cFbTHdWIdihdhI0JLlo.MdGQt7etEY226Xo7xBUCB73I2HzjDci7zKi4njfnREVBTYDaoXITXR9xEjt9MQyLemubJo519CR0u1iAS3FUlz85H_ULUlQRa8z7C.F1e1d0w4Er_8s7LjRjIAzzi2dpvZnrmNp_ID9dHWXUm0MmKKt99pOXEXnGI1dKtAsOzyOlgrkbpLO5JUbCocSUAZmkzNUd411d2lgVFu49IJ09JyZrVvhePK3jn.5cPjwDaECuB_hV_e4PxKuxv8IkhcuuzrsPyw7pX_rYjBUvsN2P0P2dUenuuQMk_5K8D1yLmc6JHX6ZXkUdfHIEyPH.8aR5HBVnFus72LAo458D4gXRPIfNa5zvtbHTcrJ3X8v4QNTyf5Z4ns_mDJ5r0QlS2dAFEvNEXAlT6C6AKYhOG9CllocwKEureKZqWy_pvfTUfkn5IZXlCSTGbY8Va3gd2OThobUjNQzhm1Fpl.xCk01JAjOeJRtY8UJbwPlfA6WHiPIeIWymDVjyKvwg_ASfhHuh_zelGDuxwCpYRA6aFXh86JzixzRhQbpAcD4vg5y5bcguDChNlaTHSgFzUxC69dMs5DhNIMwhUTwFr7b2gLXjRI.MpJNU52yeFOiE7iBOYxosGWq7zy6DT_SGCI6_0i0XYNLvzi5PASLz14xRALfLdfK6NR3i7na1s2AHy.1eW_Wjy24Xh4NUdiOYrKsyiUlVE0tXgDVxfkXtBVf8F7kSTTqTO68Ja6.wOtEozu5KKOEmWJUuk_gV1scZbYUlFYxMdBGDjTsPeRYhhAT8vW.a1pl7r.58G1zMT6ZYS7qF6s3xNatB5VihG8I_vvpwrj0P',mdrd: 'yrU6w8AxAbh_vkpVNdWSo.KI587c0rAn8GJagKiAMDw-1780829901-1.2.1.1-bgcYqtxWA6C.LtVOQmB2_XIVjaNgnlmzem8c2Uiyg_zDVpDN98tOgSQ6N3l818Z5Pb4BJIGhUcsTSO34P2QeQxyYCFHxYWvrSbYdTZus86_C56._YPne4GyOr5Lr3oQ9z2JLhxegETV.kUcIo5ZMYzxDTo58ri7Yuccospn7DOcZ_oqieRY4em1epAcEsY8xm5JHjGNBrDcEYFF_5A0W3jiMOrhjuqMFp34xBuYwEbZ7uM6DzTUrTsOHhTMdAI4ZkmRqZTWxvPuZvzdx53toMg',};var a = document.createElement(' ...

# %%
class_="text-title-large font-semibold text-text-primary dark:text-text-primary"print(soup.find_all("div", ))
# Out:
# []

# %%
for div in soup.find_all("div"):
    print(div.get("class"))
# Out:
# ['main-wrapper']
# ['main-content']
# ['h2']
